# %%
import pickle as pkl
import pandas as pd
import numpy as np
import random

random.seed(1)

# %%
labels = pkl.load(open("./data/train/labels.pkl", "rb"))
labels = pd.Series(labels)
print(labels.head())
print(labels.count())
print(labels.value_counts())
# Out:
# 0    C
# 1    C
# 2    C
# 3    C
# 4    C
# dtype: object
# 45930
# C    39912
# M     6018
# dtype: int64

# %%
labels[39912]
# Out:
# 'M'

# %%
sentences = pkl.load(open("./data/train/sentences.pkl", "rb"))
print(sentences[:5])
print(len(sentences))
# Out:
# ["J'aurai l'occasion de dire aux Français comment notre enseignement devra évoluer pour permettre à chaque jeune de trouver sa place, d'entrer dans le monde du travail, de savoir s'adapter et, à partir de là, d'acquérir, tout au long de la vie, de nouvelles compétences et de nouveaux savoirs.", 'Il est nécessaire.', "Dans votre coeur et dans votre vie, la confiance et l'enthousiasme l'emportent sur le doute.", "Pour conduire ce débat dans un esprit de véritable dialogue, je compte, si nos partenaires en sont d'accord, inviter au prochain sommet du G7, à Lyon, pour une séance de travail, le secrétaire général des Nations Unies, le président de la Banque mondiale et le directeur général du Fonds monétaire international.", "La France et l'Europe construiront ainsi un avenir de coopération avec un Proche-Orient pacifié, stable, prospère, libéré des menaces de la guerre, de la prolifération, du terrorisme."]
# 45930

# %%
sequences = pkl.load(open("./data/train/sequences.pkl", "rb"))
print(sequences[:5])
print(len(sequences))
# Out:
# [[54, 2187, 5, 320, 1, 102, 47, 74, 357, 33, 640, 613, 1377, 17, 434, 6, 144, 834, 1, 452, 69, 127, 0, 10, 1604, 18, 7, 71, 19, 152, 0, 1, 359, 34, 683, 4, 0, 6, 800, 1, 128, 0, 10, 2741, 0, 52, 25, 474, 1, 3, 99, 0, 1, 205, 880, 4, 1, 313, 2428, 2], [21, 11, 279, 2], [18, 53, 165, 4, 18, 53, 99, 0, 3, 169, 4, 5, 1466, 5, 6065, 35, 7, 364, 2], [17, 848, 27, 554, 18, 15, 175, 1, 425, 163, 0, 20, 255, 0, 77, 38, 273, 12, 44, 10, 351, 0, 4791, 25, 604, 342, 19, 1629, 0, 6, 1592, 0, 17, 16, 5191, 1, 152, 0, 7, 1065, 182, 9, 248, 567, 0, 7, 82, 1, 3, 1291, 406, 4, 7, 2036, 182, 19, 789, 1040, 461, 2], [3, 37, 4, 5, 68, 17747, 146, 15, 111, 1, 195, 39, 15, 699, 24, 912, 15240, 0, 2232, 0, 2858, 0, 4800, 9, 1810, 1, 3, 382, 0, 1, 3, 2384, 0, 19, 961, 2]]
# 45930

# %%
vocab = pkl.load(open("./data/dict.pkl", "rb"))
print(len(vocab))
print(vocab)
# Out:
# 30432
# {',': 0, 'de': 1, '.': 2, 'la': 3, 'et': 4, "l'": 5, 'à': 6, 'le': 7, 'les': 8, 'des': 9, "d'": 10, 'est': 11, 'en': 12, 'que': 13, 'qui': 14, 'un': 15, 'une': 16, 'pour': 17, 'dans': 18, 'du': 19, 'je': 20, 'il': 21, 'nous': 22, 'vous': 23, '-': 24, 'au': 25, 'a': 26, 'ce': 27, "c'": 28, 'plus': 29, "qu'": 30, 'pas': 31, 'par': 32, 'notre': 33, "s'": 34, 'sur': 35, 'ne': 36, 'france': 37, 'nos': 38, 'avec': 39, 'cette': 40, 'se': 41, 'mais': 42, 'pays': 43, 'sont': 44, 'aussi': 45, 'elle': 46, 'aux': 47, "n'": 48, 'ont': 49, 'être': 50, 'leur': 51, 'tout': 52, 'votre': 53, "j'": 54, 'tous': 55, 'son': 56, 'y': 57, '"': 58, 'on': 59, 'bien': 60, 'ces': 61, 'même': 62, 'ses': 63, 'ou': 64, 'comme': 65, 'entre': 66, ':': 67, 'europe': 68, 'sa': 69, "aujourd'hui": 70, 'monde': 71, 'doit': 72, 'faire': 73, 'français': 74, 'ai': 75, 'ils': 76, 'si': 77, 'faut': 78, 'sans': 79, 'été': 80, 'fait': 81, 'président': 82, 'où': 83, 'leurs': 84, 'cela': 85, 'avez': 86, 'très': 87, 'monsieur': 88, 'deux': 89, 'ensemble': 90, 'peut': 91, 'développement': 92, 'dont': 93, 'vos': 94, 'autres': 95, 'politique': 96, 'encore': 97, 'toutes': 98, 'vie': 99, 'avons': 100, 'ceux': 101, 'dire': 102, 'temps': 103, 'depuis': 104, 'ici': 105, 'toute': 106, 'etat': 107, 'paix': 108, 'union': 109, 'chacun': 110, 'avenir': 111, 'européenne': 112, 'beaucoup': 113, 'me': 114, 'ans': 115, 'abord': 116, 'notamment': 117, '—': 118, 'elles': 119, 'toujours': 120, 'économique': 121, 'suis': 122, 'histoire': 123, 'lui': 124, 'sécurité': 125, '?': 126, 'place': 127, 'là': 128, 'grande': 129, 'société': 130, 'parce': 131, 'premier': 132, 'soit': 133, 'cet': 134, 'devons': 135, 'entreprises': 136, 'enfin': 137, 'mon': 138, 'grand': 139, 'était': 140, 'mieux': 141, "m'": 142, 'contre': 143, 'chaque': 144, 'autre': 145, 'ainsi': 146, 'action': 147, 'sera': 148, 'doivent': 149, 'fois': 150, 'droit': 151, 'travail': 152, 'hommes': 153, ';': 154, 'volonté': 155, 'jeunes': 156, 'déjà': 157, 'respect': 158, 'également': 159, 'solidarité': 160, 'années': 161, 'avoir': 162, 'dialogue': 163, 'démocratie': 164, 'coeur': 165, 'moyens': 166, 'souvent': 167, 'alors': 168, 'confiance': 169, 'république': 170, 'part': 171, 'progrès': 172, 'homme': 173, 'service': 174, 'esprit': 175, 'celle': 176, 'liberté': 177, 'donc': 178, 'gouvernement': 179, 'moi': 180, 'car': 181, 'général': 182, 'quelques': 183, 'souhaite': 184, 'nouvelle': 185, 'française': 186, 'peu': 187, 'voudrais': 188, 'grands': 189, 'naturellement': 190, 'celui': 191, 'après': 192, 'ma': 193, 'année': 194, 'coopération': 195, 'communauté': 196, 'messieurs': 197, 'rôle': 198, 'donner': 199, '!': 200, 'non': 201, 'sommes': 202, 'force': 203, 'tant': 204, 'nouvelles': 205, 'première': 206, 'sociale': 207, 'conseil': 208, 'afrique': 209, 'mes': 210, 'état': 211, 'jamais': 212, 'sais': 213, 'sous': 214, 'quand': 215, 'culture': 216, 'emploi': 217, 'valeurs': 218, 'sûr': 219, 'oeuvre': 220, 'nouveau': 221, 'vers': 222, 'ailleurs': 223, 'trop': 224, 'mesdames': 225, 'pense': 226, 'droits': 227, 'grandes': 228, 'amitié': 229, 'nation': 230, 'internationale': 231, 'peuple': 232, 'peuples': 233, 'croissance': 234, 'etats': 235, 'dit': 236, 'nationale': 237, 'eux': 238, 'avant': 239, 'sens': 240, 'relations': 241, 'région': 242, 'domaine': 243, 'qualité': 244, 'besoin': 245, 'social': 246, 'jour': 247, 'nations': 248, 'loi': 249, 'responsabilité': 250, 'heure': 251, 'moment': 252, 'pourquoi': 253, 'économie': 254, 'compte': 255, 'soient': 256, 'êtes': 257, 'paris': 258, 'demain': 259, 'efforts': 260, 'cadre': 261, 'moins': 262, 'dès': 263, 'prendre': 264, 'celles': 265, 'ministre': 266, 'plan': 267, 'choix': 268, 'effort': 269, 'delà': 270, 'ville': 271, 'mettre': 272, 'partenaires': 273, 'ambition': 274, 'siècle': 275, 'environnement': 276, 'avait': 277, 'entreprise': 278, 'nécessaire': 279, 'pouvoir': 280, 'femmes': 281, 'mêmes': 282, 'formation': 283, 'forte': 284, 'voie': 285, 'vrai': 286, 'veux': 287, 'création': 288, 'crois': ...

# %%
def sentence_generator(labels, sentences):
    chirac = random.randint(0, 39912)
    mitterand = random.randint(39912, len(labels))
    print("Chirac: ", sentences[chirac])
    print("Mitterand: ", sentences[mitterand])
sentence_generator(labels, sentences)
# Out:
# Chirac:  C'est un très grand plaisir pour moi de participer avec vous à la clôture de ce Congrès mondial de la comptabilité.
# Mitterand:  Bien entendu, cet excès du langage, à la fois, recouvre une certaine exaltation inutile de l'esprit, mais d'autre part, il arrive que cela soit vrai.

# %%
import torch
import torch.autograd as autograd
import torch.utils.data as data

# %%
torch.cuda.is_available()
# Out:
# True

# %%
def train_test_split(labels, sentences, sequences, train_ratio=0.75):
    nb_chirac, nb_mitt = pd.Series(labels).value_counts().values
    chirac
    
    

    
train_test_split(labels, sentences, sequences)
# Out:
# 39912 6018

# %%
def build_weights(labels):
    weights = np.ones(len(labels))
    nb_chirac, nb_mitt = pd.Series(labels).value_counts().values
    print(nb_chirac / (len(labels)))
    weights[:nb_chirac] /= nb_chirac
    weights[nb_chirac:] /= nb_mitt
    return weights

print(build_weights(labels)[39911:39913])
# Out:
# 0.8689745264532985
# [2.50551213e-05 1.66168162e-04]

# %%
df = pd.DataFrame()
df['labels'] = labels
df['sentences'] = sentences
df['sequences'] = sequences
print(df.info())
print(df.head())

weights = build_weights(labels)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45930 entries, 0 to 45929
# Data columns (total 3 columns):
# labels       45930 non-null object
# sentences    45930 non-null object
# sequences    45930 non-null object
# dtypes: object(3)
# memory usage: 1.1+ MB
# None
#   labels                                          sentences  \
# 0      C  J'aurai l'occasion de dire aux Français commen...
# 1      C                                 Il est nécessaire.
# 2      C  Dans votre coeur et dans votre vie, la confian...
# 3      C  Pour conduire ce débat dans un esprit de vérit...
# 4      C  La France et l'Europe construiront ainsi un av...
#
#                                            sequences
# 0  [54, 2187, 5, 320, 1, 102, 47, 74, 357, 33, 64...
# 1                                   [21, 11, 279, 2]
# 2  [18, 53, 165, 4, 18, 53, 99, 0, 3, 169, 4, 5, ...
# 3  [17, 848, 27, 554, 18, 15, 175, 1, 425, 163, 0...
# 4  [3, 37, 4, 5, 68, 17747, 146, 15, 111, 1, 195,...
# 0.8689745264532985

# %%
from sklearn.model_selection import train_test_split

def train_test_split(df, train_ratio):
    nb_chirac, nb_mitt = df['labels'].value_counts().values
    chirac = df.iloc[:nb_chirac]
    mitt = df.iloc[nb_chirac:]
    
    x_train_chirac, x_test_chirac, y_train_chirac, y_test_chirac = train_test_split(chirac[sequences], chirac[labels], train_size=train_ratio)
    x_train_mitt, x_test_mitt, y_train_mitt, y_test_mitt = train_test_split(mitt[sequences], mitt[labels], train_size=train_ratio)
    
    x_train = np.concatenate(x_train_chirac, x_train_mitt)
    x_test = np.concatenate(x_test_chirac, x_test_mitt)
    y_train = np.concatenate(y_train_chirac, y_train_mitt)
    y_test = np.concatenate(y_)

# %%
tensor_seq = [autograd.Variable(torch.LongTensor(seq).unsqueeze(0)) for seq in sequences]
print(tensor_seq[:5])
dataset = data.TensorDataset(*tensor_seq)
sampler = data.WeightedRandomSampler(weights=weights, num_samples=1)

# %%
random.seed(1)
random.choices(tensor_seq, weights=weights)
# Out:
# [tensor([[    5,   220,     1,  1729,    36, 15886,    31,    66, 13152,     4,
#              96,     0,    66,     3, 22861,     4,     7, 22862,     2]])]
